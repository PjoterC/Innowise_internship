# %%
import pandas as pd
from pathlib import Path
data_dir = Path("data/tiktok_google_play_reviews.csv")
data = pd.read_csv(data_dir)

#data.head()
# Out:
#        reviewId userName userImage content  score  thumbsUpCount  \
# 0           NaN      NaN       NaN     NaN    NaN            NaN
# 1           NaN      NaN       NaN     NaN    NaN            NaN
# 2           NaN      NaN       NaN     NaN    NaN            NaN
# 3           NaN      NaN       NaN     NaN    NaN            NaN
# 4           NaN      NaN       NaN     NaN    NaN            NaN
# ...         ...      ...       ...     ...    ...            ...
# 307052      NaN      NaN       NaN     NaN    NaN            NaN
# 307053      NaN      NaN       NaN     NaN    NaN            NaN
# 307054      NaN      NaN       NaN     NaN    NaN            NaN
# 307055      NaN      NaN       NaN     NaN    NaN            NaN
# 307056      NaN      NaN       NaN     NaN    NaN            NaN
#
#        reviewCreatedVersion   at replyContent repliedAt
# 0                       NaN  NaN          NaN       NaN
# 1                       NaN  NaN          NaN       NaN
# ...
