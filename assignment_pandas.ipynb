# %% [markdown]
# ## The dataset is collected from the 1994 census database and contains income data.
# ### Data description:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Perform data analysis using Pandas by completing the tasks below.
# ####

# %%
import pandas as pd

# %%
# load the dataset
data = pd.read_csv("./data/adult.data.csv")
data.head()

# %% [markdown]
# **1. Count how many men and women (feature *sex*) are represented in this dataset**

# %%
# your code

# %% [markdown]
# **2. What is the average age of the men (feature *age*) across the whole dataset?**

# %%
# your code

# %% [markdown]
# **3. What is the proportion of United States citizens (feature *native-country*)?**

# %%
# your code

# %% [markdown]
# **4-5. Compute the mean and standard deviation of the age of those who earn more than 50K per year (feature *salary*) and those who earn less than 50K per year**

# %%
# your code

# %% [markdown]
# **6. Is it true that people who earn more than 50k have at least a higher education? (feature *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* or *Doctorate*)**

# %%
# your code

# %% [markdown]
# **7. Display age statistics for each race (feature *race*) and each sex. Use *groupby* and *describe*. In this way, find the maximum age of men of the *Asian-Pac-Islander* race.**

# %%
# your code

# %% [markdown]
# **8. Among whom is the proportion of high earners (>50K) greater: among married or single men (feature *marital-status*)? Consider as married those whose *marital-status* starts with *Married* (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), and consider the rest as single.**

# %%
# your code

# %% [markdown]
# **9. What is the maximum number of hours a person works per week (feature *hours-per-week*)? How many people work that many hours, and what is the percentage of high earners among them?**

# %%
# your code

# %% [markdown]
# **10. Compute the average working time (*hours-per-week*) of low and high earners (*salary*) for each country (*native-country*).**

# %%
# your code

# %% [markdown]
# **11. Group people into the age groups *young*, *adult*, *retiree*, where:**
# * *young* corresponds to 16-35 years
# * *adult* - 35-70 years
# * *retiree* - 70-100 years
#
# **Assign the name of the corresponding group for each person in a new column AgeGroup**

# %%
# your code

# %% [markdown]
# **12-13. Determine the number of people earning >50K in each of the age groups (column AgeGroup), and also output the name of the age group in which people earn more than 50K (>50K) most often**

# %%
# your code

# %% [markdown]
# **14. Group people by employment type (column occupation) and determine the number of people in each group. Then write a filtering function filter_func that returns only those groups in which the average age (column age) is no more than 40 and in which all workers work more than 5 hours per week (column hours-per-week)**

# %%
# your code
